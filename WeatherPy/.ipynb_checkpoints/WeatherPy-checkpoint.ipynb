# %%
# Observation 1:

# It does indeed get hotter overall as you move towards the equater. 


# Observation 2:

# Temperature trends in the southern hemisphere appear to be milder. 
# Although we are at the turn of seasons (i.e. Autumn and Spring), the temperature trends in the
# northern hemisphere are far more pronounced. 


# Observation 3:

# Humidity seems to increase as you move away from the equator. 
# Potentially this could contradict how "hot" it feels, but temperature changes would offset this. 


# Observation 4:

# It seems to be sunnier closer to the equator, and cloudiness rises towards the poles.

# %%
from config import gkey
from config import weatherkey
from citipy import citipy
import numpy as np
import pandas as pd
import requests
import json
from pprint import pprint
from matplotlib import pyplot as plt
from scipy import stats
import os

# %%
# create dataframe 
City_df = pd.DataFrame()
header_list = ['City','Country','Lattitude','Longitude','Temperature C','Temperature F','Humidity %','Cloudiness %','Wind Speed (mph)']
City_df = City_df.reindex(columns = header_list)
City_df['City']= City_df['City'].astype(str)
City_df['Country']= City_df['Country'].astype(str)

# %%
loopcount = 0
MaxCities = 500

savefolder = "Output/"

# start loop
while loopcount < MaxCities:
    rowlist = []
    # set random lats and longs
    rand_lat = round(np.random.uniform(-90, 90),4)
    rand_long = round(np.random.uniform(-180, 180),4)

    # get city name and counry 
    cityname = citipy.nearest_city(rand_lat,rand_long).city_name.title()
    citycountry = citipy.nearest_city(rand_lat,rand_long).country_code.upper()

    # test if city name already in list, and restart if so
    if cityname in City_df['City'].values:
        print(f'{cityname} is a Duplicate City, Skipping.')
        continue
        
    # generate url and hit API 
    full_url = base_url + cityname + comma + citycountry + '&appid=' + weatherkey
    response = requests.get(full_url) 
    parsed_response = response.json()
    
    # attempt to load data into DF, if city was found and values can be parsed 
    try:
        City_df.at[loopcount, 'City']  = cityname    
        City_df.at[loopcount, 'Country'] = citycountry
        City_df.at[loopcount, 'Temperature C'] = (parsed_response["main"]["temp_max"] - 273)
        City_df.at[loopcount, 'Temperature F'] = (parsed_response["main"]["temp_max"] * 1.8 - 457.6)
        City_df.at[loopcount, 'Lattitude'] = parsed_response["coord"]["lat"]
        City_df.at[loopcount, 'Longitude'] = parsed_response["coord"]["lon"]
        City_df.at[loopcount, 'Humidity %'] = parsed_response["main"]["humidity"]
        City_df.at[loopcount, 'Cloudiness %'] = parsed_response["clouds"]["all"]
        City_df.at[loopcount, 'Wind Speed (mph)'] = (parsed_response["wind"]["speed"] * 2.24)
        print('City found: ' + cityname + ", " + citycountry + ", #" + loopcount)
        loopcount = loopcount + 1
    except:
        print('City ' + cityname + ' not found in API! Skipping.')

# Save and output dataframe to screen
City_df.to_csv(savefolder + 'City Weather Data.csv')  
City_df.head(50)
# Out:
# City found: Besancon, FR
# City found: Punta Arenas, CL
# City found: Roebourne, AU
# City Mataura not found in API! Skipping.
# City found: Saldanha, ZA
# City Yeehaw Junction not found in API! Skipping.
# City found: Rikitea, PF
# City Khani not found in API! Skipping.
# City found: Souillac, MU
# City found: Jamestown, SH
# City found: Aklavik, CA
# City found: Port Lincoln, AU
# City found: Hobart, AU
# City found: Ribeira Grande, PT
# City found: Rio Gallegos, AR
# City found: Kaitangata, NZ
# City found: North Myrtle Beach, US
# City found: Hasaki, JP
# City found: Cidreira, BR
# City found: Fairbanks, US
# Jamestown is a Duplicate City, Skipping.
# City found: Ushuaia, AR
# City found: Tasiilaq, GL
# Rikitea is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# City found: Naze, JP
# City found: Kodiak, US
# City found: Prestea, GH
# Ushuaia is a Duplicate City, Skipping.
# City found: Kuching, MY
# City found: Aksu, KZ
# City found: Salalah, OM
# City found: Iquitos, PE
# Rikitea is a Duplicate City, Skipping.
# City Sur not found in API! Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# City Illoqqortoormiut not found in API! Skipping.
# City found: Dikson, RU
# City found: Rocha, UY
# City found: Constitucion, MX
# Jamestown is a Duplicate City, Skipping.
# City found: Korla, CN
# City found: Paamiut, GL
# City found: Tuktoyaktuk, CA
# Punta Arenas is a Duplicate City, Skipping.
# City found: Casma, PE
# City found: Jieshi, CN
# City found: Vestmannaeyjar, IS
# City found: Dubrovka, RU
# City found: Bluff, NZ
# Ribeira Grande is a Duplicate City, Skipping.
# City found: Talnakh, RU
# City found: Husavik, IS
# City found: Seymchan, RU
# City found: Felanitx, ES
# City Mys Shmidta not found in API! Skipping.
# City found: Lorengau, PG
# City found: San Patricio, MX
# City found: Ayagoz, KZ
# City found: Port Macquarie, AU
# City found: Puerto Ayora, EC
# Tuktoyaktuk is a Duplicate City, Skipping.
# City found: Grand Gaube, MU
# City Taolanaro not found in API! Skipping.
# Ushuaia is a Duplicate City, Skipping.
# City found: Santa Isabel, MX
# City found: Victoria, SC
# City found: Chuy, UY
# Punta Arenas is a Duplicate City, Skipping.
# City found: Biak, ID
# City found: Vaini, TO
# City found: Sao Borja, BR
# City found: Ippy, CF
# Punta Arenas is a Duplicate City, Skipping.
# Cidreira is a Duplicate City, Skipping.
# City Bolungarvik not found in API! Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# City Barentsburg not found in API! Skipping.
# City found: Sao Filipe, CV
# City found: Saint-Malo, FR
# City found: Busselton, AU
# City found: Butaritari, KI
# City found: Vikulovo, RU
# City found: Hilo, US
# City found: Hermanus, ZA
# City found: Saint Simons, US
# Butaritari is a Duplicate City, Skipping.
# City found: Belaya Gora, RU
# City found: Palmas, BR
# City found: Saint-Philippe, RE
# City found: Huilong, CN
# City found: Isangel, VU
# City found: Gisborne, NZ
# City found: East London, ZA
# City Grand River South East not found in API! Skipping.
# Vaini is a Duplicate City, Skipping.
# City found: Kyabe, TD
# City found: Torbay, CA
# City Guatemalita not found in API! Skipping.
# City found: Port Alfred, ZA
# Vaini is a Duplicate City, Skipping.
# City found: Tailai, CN
# City found: Lodja, CD
# City found: Mahebourg, MU
# Dikson is a Duplicate City, Skipping.
# City Banmo not found in API! Skipping.
# Bluff is a Duplicate City, Skipping.
# Busselton is a Duplicate City, Skipping.
# City Mataura not found in API! Skipping.
# City found: Haines Junction, CA
# City found: Bam, IR
# City found: Provideniya, RU
# City found: Hambantota, LK
# City found: Huarmey, PE
# City found: Tres Arroyos, AR
# Kaitangata is a Duplicate City, Skipping.
# City found: Longfeng, CN
# Hilo is a Duplicate City, Skipping.
# Vaini is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# Port Alfred is a Duplicate City, Skipping.
# Talnakh is a Duplicate City, Skipping.
# City found: Upernavik, GL
# Chuy is a Duplicate City, Skipping.
# City found: Maceio, BR
# City Taolanaro not found in API! Skipping.
# Vaini is a Duplicate City, Skipping.
# City found: Awjilah, LY
# City found: Albany, AU
# City Tsihombe not found in API! Skipping.
# Rikitea is a Duplicate City, Skipping.
# Hobart is a Duplicate City, Skipping.
# City found: Severomuysk, RU
# City found: Barrow, US
# City found: Port Hardy, CA
# City found: Puerto Escondido, MX
# City found: Geraldton, AU
# Belaya Gora is a Duplicate City, Skipping.
# City found: Sitka, US
# City found: Kargil, IN
# City found: Atyrau, KZ
# City found: Bredasdorp, ZA
# Cidreira is a Duplicate City, Skipping.
# City found: Georgetown, SH
# City found: Atuona, PF
# City found: Esperance, AU
# City Skalistyy not found in API! Skipping.
# City Tsihombe not found in API! Skipping.
# Chuy is a Duplicate City, Skipping.
# City found: Imamoglu, TR
# City found: Kenitra, MA
# Punta Arenas is a Duplicate City, Skipping.
# City found: Myaundzha, RU
# Busselton is a Duplicate City, Skipping.
# City Karpuninskiy not found in API! Skipping.
# City found: Shingu, JP
# Hobart is a Duplicate City, Skipping.
# City found: Palmer, US
# City found: Ostersund, SE
# City found: Chokurdakh, RU
# City found: Pafos, CY
# City found: Roma, AU
# City found: Carnarvon, AU
# City found: Rapid Valley, US
# Busselton is a Duplicate City, Skipping.
# City found: Coquimbo, CL
# City found: Santa Fe, CU
# City found: Never, RU
# Carnarvon is a Duplicate City, Skipping.
# Jamestown is a Duplicate City, Skipping.
# City found: Bojonegoro, ID
# Upernavik is a Duplicate City, Skipping.
# Tasiilaq is a Duplicate City, Skipping.
# City found: Yellowknife, CA
# City found: Porto Novo, CV
# Saint-Philippe is a Duplicate City, Skipping.
# City found: Avarua, CK
# Jamestown is a Duplicate City, Skipping.
# City Taolanaro not found in API! Skipping.
# City Barentsburg not found in API! Skipping.
# Hermanus is a Duplicate City, Skipping.
# Atuona is a Duplicate City, Skipping.
# Hilo is a Duplicate City, Skipping.
# Atuona is a Duplicate City, Skipping.
# City found: Longyearbyen, SJ
# City found: Butia, BR
# Rikitea is a Duplicate City, Skipping.
# Atuona is a Duplicate City, Skipping.
# City found: Ambilobe, MG
# City found: Mogadishu, SO
# City found: Barcelos, BR
# City Taolanaro not found in API! Skipping.
# Albany is a Duplicate City, Skipping.
# City Attawapiskat not found in API! Skipping.
# Kaitangata is a Duplicate City, Skipping.
# City Mataura not found in API! Skipping.
# City found: Marsh Harbour, BS
# City found: Samana, DO
# Vaini is a Duplicate City, Skipping.
# City found: Nikolskoye, RU
# City Ngukurr not found in API! Skipping.
# City Taolanaro not found in API! Skipping.
# City found: Knysna, ZA
# City found: Imbituba, BR
# Dikson is a Duplicate City, Skipping.
# City found: Maun, BW
# Jamestown is a Duplicate City, Skipping.
# Aksu is a Duplicate City, Skipping.
# Talnakh is a Duplicate City, Skipping.
# City Airai not found in API! Skipping.
# Jamestown is a Duplicate City, Skipping.
# City found: Gornopravdinsk, RU
# City Kuche not found in API! Skipping.
# Bluff is a Duplicate City, Skipping.
# City found: Fort Nelson, CA
# City found: Selikhino, RU
# Nikolskoye is a Duplicate City, Skipping.
# City Tonj not found in API! Skipping.
# City Vaitupu not found in API! Skipping.
# City found: Auki, SB
# City Mergui not found in API! Skipping.
# City found: Barbacoas, CO
# Atuona is a Duplicate City, Skipping.
# City found: Kenai, US
# City found: Toucheng, TW
# City found: Cape Town, ZA
# Albany is a Duplicate City, Skipping.
# City found: Sheridan, US
# City found: Khatanga, RU
# Rikitea is a Duplicate City, Skipping.
# City found: Kalmunai, LK
# City found: Parelhas, BR
# Albany is a Duplicate City, Skipping.
# City found: Taoudenni, ML
# City found: Eloy, US
# Ushuaia is a Duplicate City, Skipping.
# City Tsihombe not found in API! Skipping.
# City found: Coihaique, CL
# City found: Byron Bay, AU
# City found: Ipixuna, BR
# City found: Tiksi, RU
# Dikson is a Duplicate City, Skipping.
# Puerto Ayora is a Duplicate City, Skipping.
# City found: Labuhan, ID
# City found: Ohara, JP
# Bredasdorp is a Duplicate City, Skipping.
# City found: Burnie, AU
# City found: Namatanai, PG
# Hermanus is a Duplicate City, Skipping.
# City found: Praia Da Vitoria, PT
# City found: Aykhal, RU
# City found: Bellmead, US
# Upernavik is a Duplicate City, Skipping.
# City found: Ancud, CL
# City found: Ndele, CF
# Saint-Philippe is a Duplicate City, Skipping.
# Hilo is a Duplicate City, Skipping.
# Hilo is a Duplicate City, Skipping.
# Busselton is a Duplicate City, Skipping.
# City Belushya Guba not found in API! Skipping.
# City found: Kapaa, US
# Ushuaia is a Duplicate City, Skipping.
# City Barentsburg not found in API! Skipping.
# City Belushya Guba not found in API! Skipping.
# City found: Acarau, BR
# City found: Yar-Sale, RU
# City Amderma not found in API! Skipping.
# City found: Songjianghe, CN
# City found: Limanowa, PL
# City found: Saskylakh, RU
# City found: Huambo, AO
# Bluff is a Duplicate City, Skipping.
# City found: Bundaberg, AU
# City Amderma not found in API! Skipping.
# Hermanus is a Duplicate City, Skipping.
# City found: Samarai, PG
# Vaini is a Duplicate City, Skipping.
# Hermanus is a Duplicate City, Skipping.
# City found: Opuwo, NA
# City found: Cockburn Town, TC
# City Codrington not found in API! Skipping.
# Bredasdorp is a Duplicate City, Skipping.
# City found: Arraial Do Cabo, BR
# City found: Adrar, DZ
# City found: Road Town, VG
# Port Alfred is a Duplicate City, Skipping.
# City found: Taitung, TW
# Hobart is a Duplicate City, Skipping.
# Butaritari is a Duplicate City, Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# City found: Bemidji, US
# Busselton is a Duplicate City, Skipping.
# City found: Sao Jose Da Coroa Grande, BR
# Cape Town is a Duplicate City, Skipping.
# City Tsihombe not found in API! Skipping.
# Port Hardy is a Duplicate City, Skipping.
# City found: Lebedyan, RU
# City found: Ponta Do Sol, CV
# City found: Muravlenko, RU
# City found: San Cristobal, EC
# City found: Nioki, CD
# Victoria is a Duplicate City, Skipping.
# Bluff is a Duplicate City, Skipping.
# City found: Falam, MM
# City found: Saint-Augustin, CA
# Punta Arenas is a Duplicate City, Skipping.
# Naze is a Duplicate City, Skipping.
# City found: Thompson, CA
# Rikitea is a Duplicate City, Skipping.
# City found: Hofn, IS
# Punta Arenas is a Duplicate City, Skipping.
# City Sukhoverkovo not found in API! Skipping.
# Bluff is a Duplicate City, Skipping.
# Busselton is a Duplicate City, Skipping.
# City found: Kaiyuan, CN
# Ushuaia is a Duplicate City, Skipping.
# City found: Sri Aman, MY
# City found: Champerico, GT
# Hasaki is a Duplicate City, Skipping.
# City found: Katsuura, JP
# Georgetown is a Duplicate City, Skipping.
# City found: Bambous Virieux, MU
# City found: Olinda, BR
# Rikitea is a Duplicate City, Skipping.
# City found: Kanchanaburi, TH
# Dikson is a Duplicate City, Skipping.
# City found: Srednekolymsk, RU
# Busselton is a Duplicate City, Skipping.
# City found: Vao, NC
# City Mataura not found in API! Skipping.
# City found: Narodychi, UA
# Fairbanks is a Duplicate City, Skipping.
# Rikitea is a Duplicate City, Skipping.
# City found: Sabinas Hidalgo, MX
# City found: Karratha, AU
# City found: Kapit, MY
# San Patricio is a Duplicate City, Skipping.
# Vaini is a Duplicate City, Skipping.
# Albany is a Duplicate City, Skipping.
# Ponta Do Sol is a Duplicate City, Skipping.
# City found: Burhar, IN
# City found: Iqaluit, CA
# Bredasdorp is a Duplicate City, Skipping.
# City found: Gizo, SB
# Salalah is a Duplicate City, Skipping.
# City found: Qasigiannguit, GL
# Avarua is a Duplicate City, Skipping.
# Longyearbyen is a Duplicate City, Skipping.
# City found: Do Gonbadan, IR
# Jamestown is a Duplicate City, Skipping.
# Dikson is a Duplicate City, Skipping.
# Rikitea is a Duplicate City, Skipping.
# City found: New Norfolk, AU
# City found: Mar Del Plata, AR
# Jamestown is a Duplicate City, Skipping.
# City found: Te Anau, NZ
# City found: Tripoli, LY
# Thompson is a Duplicate City, Skipping.
# Longyearbyen is a Duplicate City, Skipping.
# Hilo is a Duplicate City, Skipping.
# Kapaa is a Duplicate City, Skipping.
# Barrow is a Duplicate City, Skipping.
# City found: Waingapu, ID
# Busselton is a Duplicate City, Skipping.
# City found: Hobyo, SO
# City found: Xining, CN
# City found: Castro, CL
# City found: Saint George, BM
# City found: Cherskiy, RU
# City Tsihombe not found in API! Skipping.
# City Asau not found in API! Skipping.
# Cape Town is a Duplicate City, Skipping.
# Mar Del Plata is a Duplicate City, Skipping.
# Nikolskoye is a Duplicate City, Skipping.
# Vaini is a Duplicate City, Skipping.
# Cape Town is a Duplicate City, Skipping.
# Bambous Virieux is a Duplicate City, Skipping.
# City found: Bengkulu, ID
# City found: Lompoc, US
# City found: Copala, MX
# Opuwo is a Duplicate City, Skipping.
# Georgetown is a Duplicate City, Skipping.
# City found: Komsomolskiy, RU
# City found: Lebu, CL
# Puerto Ayora is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# City found: Tuatapere, NZ
# City found: Naryan-Mar, RU
# City found: Lazaro Cardenas, MX
# Albany is a Duplicate City, Skipping.
# City Lata not found in API! Skipping.
# City found: Pevek, RU
# City found: Luderitz, NA
# East London is a Duplicate City, Skipping.
# Chokurdakh is a Duplicate City, Skipping.
# City found: Ambatondrazaka, MG
# City found: Long Xuyen, VN
# Vaini is a Duplicate City, Skipping.
# Kodiak is a Duplicate City, Skipping.
# City found: Lahaina, US
# City Mataura not found in API! Skipping.
# City found: Lyaskelya, RU
# San Patricio is a Duplicate City, Skipping.
# Luderitz is a Duplicate City, Skipping.
# City found: Alta Floresta, BR
# Kapaa is a Duplicate City, Skipping.
# Tuktoyaktuk is a Duplicate City, Skipping.
# City found: Kruisfontein, ZA
# Hofn is a Duplicate City, Skipping.
# City found: Victor Harbor, AU
# City found: Muros, ES
# City Artyk not found in API! Skipping.
# Pevek is a Duplicate City, Skipping.
# City Belushya Guba not found in API! Skipping.
# Tasiilaq is a Duplicate City, Skipping.
# Kapaa is a Duplicate City, Skipping.
# Barrow is a Duplicate City, Skipping.
# City found: Mackay, AU
# Hobart is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# Longyearbyen is a Duplicate City, Skipping.
# City found: Port Augusta, AU
# City Ginda not found in API! Skipping.
# City Taolanaro not found in API! Skipping.
# City found: Antalaha, MG
# City Ruatoria not found in API! Skipping.
# City Mataura not found in API! Skipping.
# City found: Williamsburg, US
# Hermanus is a Duplicate City, Skipping.
# City found: Luanda, AO
# City found: Kushmurun, KZ
# City found: Boda, CF
# City found: Sokolo, ML
# Hobart is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# Albany is a Duplicate City, Skipping.
# Bambous Virieux is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# City found: Yichang, CN
# Bluff is a Duplicate City, Skipping.
# Rikitea is a Duplicate City, Skipping.
# Rikitea is a Duplicate City, Skipping.
# Tuktoyaktuk is a Duplicate City, Skipping.
# City found: Vanavara, RU
# City found: Makakilo City, US
# Port Alfred is a Duplicate City, Skipping.
# Rikitea is a Duplicate City, Skipping.
# City found: Rawson, AR
# City found: Hiroshima, JP
# City found: Syamzha, RU
# City found: Ozinki, RU
# Kaitangata is a Duplicate City, Skipping.
# Tuktoyaktuk is a Duplicate City, Skipping.
# City found: Vvedenskoye, RU
# Barrow is a Duplicate City, Skipping.
# City Belushya Guba not found in API! Skipping.
# City found: Washington, US
# Vaini is a Duplicate City, Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# City found: Sambo Creek, HN
# City found: Ewa Beach, US
# City found: Nome, US
# Jamestown is a Duplicate City, Skipping.
# City Mataura not found in API! Skipping.
# City found: Visnes, NO
# Cidreira is a Duplicate City, Skipping.
# City found: Durban, ZA
# City found: Eston, CA
# Provideniya is a Duplicate City, Skipping.
# City found: La Orilla, MX
# Tuktoyaktuk is a Duplicate City, Skipping.
# Bluff is a Duplicate City, Skipping.
# City found: Chlorakas, CY
# Dikson is a Duplicate City, Skipping.
# Albany is a Duplicate City, Skipping.
# City Tsihombe not found in API! Skipping.
# City found: Cururupu, BR
# Esperance is a Duplicate City, Skipping.
# Cape Town is a Duplicate City, Skipping.
# Carnarvon is a Duplicate City, Skipping.
# City found: Axim, GH
# City Leirvik not found in API! Skipping.
# City found: Nago, JP
# City found: Guerrero Negro, MX
# Khatanga is a Duplicate City, Skipping.
# Te Anau is a Duplicate City, Skipping.
# City found: Shibetsu, JP
# Kapaa is a Duplicate City, Skipping.
# Rikitea is a Duplicate City, Skipping.
# Hobart is a Duplicate City, Skipping.
# City found: Fukue, JP
# Carnarvon is a Duplicate City, Skipping.
# City found: Richards Bay, ZA
# Albany is a Duplicate City, Skipping.
# Busselton is a Duplicate City, Skipping.
# City found: Poum, NC
# City found: Kavieng, PG
# Ushuaia is a Duplicate City, Skipping.
# City found: Kununurra, AU
# Pevek is a Duplicate City, Skipping.
# Bluff is a Duplicate City, Skipping.
# Souillac is a Duplicate City, Skipping.
# City found: Aswan, EG
# Vaini is a Duplicate City, Skipping.
# City found: Vardo, NO
# Torbay is a Duplicate City, Skipping.
# City Amderma not found in API! Skipping.
# City found: Moerai, PF
# Puerto Ayora is a Duplicate City, Skipping.
# City Rawannawi not found in API! Skipping.
# City found: Yumen, CN
# City Mataura not found in API! Skipping.
# City found: Cayenne, GF
# Vaini is a Duplicate City, Skipping.
# Kapaa is a Duplicate City, Skipping.
# City Babanusah not found in API! Skipping.
# Saint George is a Duplicate City, Skipping.
# East London is a Duplicate City, Skipping.
# Hobart is a Duplicate City, Skipping.
# City Illoqqortoormiut not found in API! Skipping.
# Tuktoyaktuk is a Duplicate City, Skipping.
# City found: Ayan, RU
# Shingu is a Duplicate City, Skipping.
# Vaini is a Duplicate City, Skipping.
# City found: Willowmore, ZA
# Ushuaia is a Duplicate City, Skipping.
# Bredasdorp is a Duplicate City, Skipping.
# Albany is a Duplicate City, Skipping.
# Butaritari is a Duplicate City, Skipping.
# City found: Faanui, PF
# Hilo is a Duplicate City, Skipping.
# City Karaul not found in API! Skipping.
# Bengkulu is a Duplicate City, Skipping.
# City found: Doha, QA
# City found: Tahta, EG
# Kapaa is a Duplicate City, Skipping.
# City found: Beidao, CN
# Khatanga is a Duplicate City, Skipping.
# City found: Barwadih, IN
# Bengkulu is a Duplicate City, Skipping.
# City found: Oriximina, BR
# Arraial Do Cabo is a Duplicate City, Skipping.
# Lompoc is a Duplicate City, Skipping.
# Albany is a Duplicate City, Skipping.
# City found: Balykshi, KZ
# Provideniya is a Duplicate City, Skipping.
# Puerto Ayora is a Duplicate City, Skipping.
# City found: Terrak, NO
# Yellowknife is a Duplicate City, Skipping.
# City Bolsheustikinskoye not found in API! Skipping.
# Rikitea is a Duplicate City, Skipping.
# City found: Ilulissat, GL
# Rikitea is a Duplicate City, Skipping.
# Albany is a Duplicate City, Skipping.
# Luderitz is a Duplicate City, Skipping.
# City Gurgan not found in API! Skipping.
# Kapaa is a Duplicate City, Skipping.
# Saint-Philippe is a Duplicate City, Skipping.
# Tuktoyaktuk is a Duplicate City, Skipping.
# City found: Male, MV
# City found: Beloha, MG
# Busselton is a Duplicate City, Skipping.
# Avarua is a Duplicate City, Skipping.
# City found: Havoysund, NO
# Kruisfontein is a Duplicate City, Skipping.
# Vestmannaeyjar is a Duplicate City, Skipping.
# City found: Cairns, AU
# City found: Batagay-Alyta, RU
# City found: Polistena, IT
# City found: Wisconsin Rapids, US
# Thompson is a Duplicate City, Skipping.
# City Vaitupu not found in API! Skipping.
# City found: Soyo, AO
# City found: Dingle, IE
# City found: Sinop, TR
# Guerrero Negro is a Duplicate City, Skipping.
# City found: Nizhniy Kuranakh, RU
# City found: Padang, ID
# City found: Touros, BR
# Ushuaia is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# Puerto Escondido is a Duplicate City, Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# City found: Bow Island, CA
# Ushuaia is a Duplicate City, Skipping.
# City found: Raudeberg, NO
# City found: Mossendjo, CG
# Ushuaia is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# City found: Sotouboua, TG
# Dingle is a Duplicate City, Skipping.
# City Mataura not found in API! Skipping.
# City Barentsburg not found in API! Skipping.
# City Taolanaro not found in API! Skipping.
# Hermanus is a Duplicate City, Skipping.
# City found: Tongliao, CN
# Puerto Ayora is a Duplicate City, Skipping.
# City found: Smithers, CA
# Tuktoyaktuk is a Duplicate City, Skipping.
# City found: Hami, CN
# Tuktoyaktuk is a Duplicate City, Skipping.
# City found: Broken Hill, AU
# Albany is a Duplicate City, Skipping.
# City Artyk not found in API! Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# Albany is a Duplicate City, Skipping.
# City found: Zyryanovsk, KZ
# Bredasdorp is a Duplicate City, Skipping.
# Butaritari is a Duplicate City, Skipping.
# City found: Nivala, FI
# Antalaha is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# City found: Kamina, CD
# Vaini is a Duplicate City, Skipping.
# City found: Dunedin, NZ
# Constitucion is a Duplicate City, Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# City found: Pangnirtung, CA
# Busselton is a Duplicate City, Skipping.
# Saskylakh is a Duplicate City, Skipping.
# Mahebourg is a Duplicate City, Skipping.
# Hermanus is a Duplicate City, Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# Busselton is a Duplicate City, Skipping.
# Kodiak is a Duplicate City, Skipping.
# City Illoqqortoormiut not found in API! Skipping.
# City found: Qaanaaq, GL
# Hobart is a Duplicate City, Skipping.
# Hermanus is a Duplicate City, Skipping.
# Geraldton is a Duplicate City, Skipping.
# City found: Ambon, ID
# Barrow is a Duplicate City, Skipping.
# Jamestown is a Duplicate City, Skipping.
# Karratha is a Duplicate City, Skipping.
# Geraldton is a Duplicate City, Skipping.
# City found: Mahina, PF
# City found: Severo-Kurilsk, RU
# Chuy is a Duplicate City, Skipping.
# Barrow is a Duplicate City, Skipping.
# Cape Town is a Duplicate City, Skipping.
# City Illoqqortoormiut not found in API! Skipping.
# City found: Kloulklubed, PW
# Rikitea is a Duplicate City, Skipping.
# City found: Pemangkat, ID
# Bluff is a Duplicate City, Skipping.
# Bredasdorp is a Duplicate City, Skipping.
# Georgetown is a Duplicate City, Skipping.
# Kapaa is a Duplicate City, Skipping.
# Saint-Philippe is a Duplicate City, Skipping.
# Thompson is a Duplicate City, Skipping.
# Dikson is a Duplicate City, Skipping.
# Richards Bay is a Duplicate City, Skipping.
# Yar-Sale is a Duplicate City, Skipping.
# City found: Diu, IN
# Ancud is a Duplicate City, Skipping.
# Saldanha is a Duplicate City, Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# City found: Kongolo, CD
# City found: Sabzevar, IR
# City found: Sibanicu, CU
# Mar Del Plata is a Duplicate City, Skipping.
# City found: Susanville, US
# City Attawapiskat not found in API! Skipping.
# Shingu is a Duplicate City, Skipping.
# City found: Parana, BR
# City Taolanaro not found in API! Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# City found: Erzin, RU
# City found: Leh, IN
# Puerto Ayora is a Duplicate City, Skipping.
# City found: Nanortalik, GL
# Broken Hill is a Duplicate City, Skipping.
# Vaini is a Duplicate City, Skipping.
# City found: Easton, US
# City found: Williams Lake, CA
# City found: Norman Wells, CA
# City found: Eyl, SO
# Ushuaia is a Duplicate City, Skipping.
# Avarua is a Duplicate City, Skipping.
# City found: Mehamn, NO
# Hermanus is a Duplicate City, Skipping.
# Rikitea is a Duplicate City, Skipping.
# City found: Fortuna, US
# City Belushya Guba not found in API! Skipping.
# Chuy is a Duplicate City, Skipping.
# City Mataura not found in API! Skipping.
# City found: Chifeng, CN
# Rikitea is a Duplicate City, Skipping.
# Hobart is a Duplicate City, Skipping.
# Cape Town is a Duplicate City, Skipping.
# Fortuna is a Duplicate City, Skipping.
# City Attawapiskat not found in API! Skipping.
# City found: Umm Kaddadah, SD
# Erzin is a Duplicate City, Skipping.
# City found: Thanh Hoa, VN
# Ribeira Grande is a Duplicate City, Skipping.
# City found: Praia, CV
# Atuona is a Duplicate City, Skipping.
# Rikitea is a Duplicate City, Skipping.
# City found: Asfi, MA
# City Asau not found in API! Skipping.
# Saint-Philippe is a Duplicate City, Skipping.
# Georgetown is a Duplicate City, Skipping.
# San Patricio is a Duplicate City, Skipping.
# Thompson is a Duplicate City, Skipping.
# Georgetown is a Duplicate City, Skipping.
# Victoria is a Duplicate City, Skipping.
# City found: Beringovskiy, RU
# City found: Kamenka, RU
# City found: Hithadhoo, MV
# San Patricio is a Duplicate City, Skipping.
# City found: Lagoa, PT
# East London is a Duplicate City, Skipping.
# Puerto Ayora is a Duplicate City, Skipping.
# Hobart is a Duplicate City, Skipping.
# City found: Rabo De Peixe, PT
# City found: Waitati, NZ
# City found: Clyde River, CA
# City found: Pitimbu, BR
# Puerto Ayora is a Duplicate City, Skipping.
# New Norfolk is a Duplicate City, Skipping.
# City found: Yucca Valley, US
# City Meyungs not found in API! Skipping.
# City Taolanaro not found in API! Skipping.
# Cape Town is a Duplicate City, Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# Cayenne is a Duplicate City, Skipping.
# Pevek is a Duplicate City, Skipping.
# Hobart is a Duplicate City, Skipping.
# City Jujuy not found in API! Skipping.
# Sitka is a Duplicate City, Skipping.
# Kodiak is a Duplicate City, Skipping.
# Qaanaaq is a Duplicate City, Skipping.
# City Barentsburg not found in API! Skipping.
# City found: Mackenzie, CA
# City found: Ust-Omchug, RU
# City found: Ostrovnoy, RU
# City Illoqqortoormiut not found in API! Skipping.
# Dikson is a Duplicate City, Skipping.
# Barrow is a Duplicate City, Skipping.
# City found: Urumqi, CN
# City Mataura not found in API! Skipping.
# City found: Biltine, TD
# Rikitea is a Duplicate City, Skipping.
# Provideniya is a Duplicate City, Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# Barcelos is a Duplicate City, Skipping.
# City found: Troina, IT
# Lazaro Cardenas is a Duplicate City, Skipping.
# City found: Berlevag, NO
# Kapaa is a Duplicate City, Skipping.
# Severo-Kurilsk is a Duplicate City, Skipping.
# City Grand River South East not found in API! Skipping.
# City Airai not found in API! Skipping.
# City found: Jyvaskyla, FI
# Rikitea is a Duplicate City, Skipping.
# Hobart is a Duplicate City, Skipping.
# City found: Port Blair, IN
# City found: Christchurch, NZ
# Tiksi is a Duplicate City, Skipping.
# Dingle is a Duplicate City, Skipping.
# Hithadhoo is a Duplicate City, Skipping.
# Hithadhoo is a Duplicate City, Skipping.
# City found: Verkhoyansk, RU
# Burnie is a Duplicate City, Skipping.
# City Dien Bien not found in API! Skipping.
# City Kazalinsk not found in API! Skipping.
# City Mataura not found in API! Skipping.
# City found: Hovd, MN
# City found: North Bend, US
# Bluff is a Duplicate City, Skipping.
# Cape Town is a Duplicate City, Skipping.
# Sao Filipe is a Duplicate City, Skipping.
# Ayan is a Duplicate City, Skipping.
# Jamestown is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# City Tabukiniberu not found in API! Skipping.
# Rikitea is a Duplicate City, Skipping.
# City found: Olafsvik, IS
# Nikolskoye is a Duplicate City, Skipping.
# Puerto Ayora is a Duplicate City, Skipping.
# Dingle is a Duplicate City, Skipping.
# Havoysund is a Duplicate City, Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# Puerto Ayora is a Duplicate City, Skipping.
# Butaritari is a Duplicate City, Skipping.
# Rikitea is a Duplicate City, Skipping.
# Rikitea is a Duplicate City, Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# City found: Sangar, RU
# City found: Le Vauclin, MQ
# Faanui is a Duplicate City, Skipping.
# City found: Bathsheba, BB
# Albany is a Duplicate City, Skipping.
# Vaini is a Duplicate City, Skipping.
# City found: Kungurtug, RU
# City found: Moron, MN
# City Mys Shmidta not found in API! Skipping.
# City found: Itarema, BR
# Port Alfred is a Duplicate City, Skipping.
# City Samusu not found in API! Skipping.
# Atuona is a Duplicate City, Skipping.
# Nikolskoye is a Duplicate City, Skipping.
# City Taolanaro not found in API! Skipping.
# Albany is a Duplicate City, Skipping.
# City found: Zwedru, LR
# Tiksi is a Duplicate City, Skipping.
# City found: Trofors, NO
# Rikitea is a Duplicate City, Skipping.
# Castro is a Duplicate City, Skipping.
# City found: Jonava, LT
# City found: Florianopolis, BR
# City found: Krasnoturansk, RU
# City Amderma not found in API! Skipping.
# City found: Chinchani, IN
# Qaanaaq is a Duplicate City, Skipping.
# Sao Filipe is a Duplicate City, Skipping.
# Hermanus is a Duplicate City, Skipping.
# City found: Corrente, BR
# City found: Kosh-Agach, RU
# City found: Evensk, RU
# Hasaki is a Duplicate City, Skipping.
# City Samusu not found in API! Skipping.
# Hermanus is a Duplicate City, Skipping.
# Rio Gallegos is a Duplicate City, Skipping.
# City found: Buala, SB
# City found: Bontang, ID
# Bluff is a Duplicate City, Skipping.
# City found: Anshun, CN
# City found: Rundu, NA
# Kapaa is a Duplicate City, Skipping.
# City found: Ribas Do Rio Pardo, BR
# City found: Metro, ID
# Tiksi is a Duplicate City, Skipping.
# Rikitea is a Duplicate City, Skipping.
# Hobart is a Duplicate City, Skipping.
# City found: Brigantine, US
# City found: Bethel, US
# Husavik is a Duplicate City, Skipping.
# City Taolanaro not found in API! Skipping.
# City found: Salym, RU
# City Warqla not found in API! Skipping.
# Kapaa is a Duplicate City, Skipping.
# City found: Mandalgovi, MN
# Korla is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# Rikitea is a Duplicate City, Skipping.
# City found: Cabo San Lucas, MX
# City Barentsburg not found in API! Skipping.
# City Chagda not found in API! Skipping.
# Road Town is a Duplicate City, Skipping.
# City found: Namibe, AO
# Butaritari is a Duplicate City, Skipping.
# Tuktoyaktuk is a Duplicate City, Skipping.
# Rikitea is a Duplicate City, Skipping.
# City found: Qaqortoq, GL
# Albany is a Duplicate City, Skipping.
# Padang is a Duplicate City, Skipping.
# City Mataura not found in API! Skipping.
# City found: Bunia, CD
# Cherskiy is a Duplicate City, Skipping.
# Isangel is a Duplicate City, Skipping.
# City found: Sinnai, IT
# Punta Arenas is a Duplicate City, Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# Vaini is a Duplicate City, Skipping.
# City found: Hurghada, EG
# Hofn is a Duplicate City, Skipping.
# Talnakh is a Duplicate City, Skipping.
# City found: Mikhaylovka, KZ
# Bengkulu is a Duplicate City, Skipping.
# Busselton is a Duplicate City, Skipping.
# City Belushya Guba not found in API! Skipping.
# City Barentsburg not found in API! Skipping.
# City found: Ust-Nera, RU
# Punta Arenas is a Duplicate City, Skipping.
# City found: Seoul, KR
# City found: Stornoway, GB
# Norman Wells is a Duplicate City, Skipping.
# Rikitea is a Duplicate City, Skipping.
# City found: Leningradskiy, RU
# Faanui is a Duplicate City, Skipping.
# City found: Clinton, US
# City Illoqqortoormiut not found in API! Skipping.
# City found: Lappeenranta, FI
# Lebu is a Duplicate City, Skipping.
# Salalah is a Duplicate City, Skipping.
# City found: Ungureni, RO
# City found: Mecca, SA
# Butaritari is a Duplicate City, Skipping.
# Padang is a Duplicate City, Skipping.
# City Barentsburg not found in API! Skipping.
# Hambantota is a Duplicate City, Skipping.
# Kaitangata is a Duplicate City, Skipping.
# Tuktoyaktuk is a Duplicate City, Skipping.
# Barentsburg is a Duplicate City, Skipping.
# Tuatapere is a Duplicate City, Skipping.
# City found: Maputo, MZ
# Hithadhoo is a Duplicate City, Skipping.
# City Luan not found in API! Skipping.
# Hobart is a Duplicate City, Skipping.
# Bethel is a Duplicate City, Skipping.
# Nanortalik is a Duplicate City, Skipping.
# Pangnirtung is a Duplicate City, Skipping.
# Hobart is a Duplicate City, Skipping.
# Lebu is a Duplicate City, Skipping.
# City found: Port Elizabeth, ZA
# Albany is a Duplicate City, Skipping.
# Jamestown is a Duplicate City, Skipping.
# Vaini is a Duplicate City, Skipping.
# Hithadhoo is a Duplicate City, Skipping.
# City found: Rumphi, MW
# Albany is a Duplicate City, Skipping.
# City found: Mae Sai, TH
# City found: Zaragoza, MX
# City Saleaula not found in API! Skipping.
# Rikitea is a Duplicate City, Skipping.
# City found: Bilibino, RU
# City found: Moose Factory, CA
# Souillac is a Duplicate City, Skipping.
# Hithadhoo is a Duplicate City, Skipping.
# Bambous Virieux is a Duplicate City, Skipping.
# Bluff is a Duplicate City, Skipping.
# Hilo is a Duplicate City, Skipping.
# City Illoqqortoormiut not found in API! Skipping.
# Atuona is a Duplicate City, Skipping.
# City found: Pasvalys, LT
# City found: Tautira, PF
# City Marzuq not found in API! Skipping.
# Rikitea is a Duplicate City, Skipping.
# City Taolanaro not found in API! Skipping.
# Cabo San Lucas is a Duplicate City, Skipping.
# Kapaa is a Duplicate City, Skipping.
# City found: San Quintin, MX
# Komsomolskiy is a Duplicate City, Skipping.
# Busselton is a Duplicate City, Skipping.
# Ribeira Grande is a Duplicate City, Skipping.
# City found: Bud, NO
# Beringovskiy is a Duplicate City, Skipping.
# Norman Wells is a Duplicate City, Skipping.
# City Mataura not found in API! Skipping.
# City found: Tiarei, PF
# Upernavik is a Duplicate City, Skipping.
# City Illoqqortoormiut not found in API! Skipping.
# City found: Kuah, MY
# City Barawe not found in API! Skipping.
# City Mataura not found in API! Skipping.
# Bredasdorp is a Duplicate City, Skipping.
# City found: Yulara, AU
# Dikson is a Duplicate City, Skipping.
# City Mataura not found in API! Skipping.
# Ponta Do Sol is a Duplicate City, Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# City found: Tigil, RU
# Yar-Sale is a Duplicate City, Skipping.
# Albany is a Duplicate City, Skipping.
# City found: Estelle, US
# Esperance is a Duplicate City, Skipping.
# Vaini is a Duplicate City, Skipping.
# City found: Vejprty, CZ
# Hilo is a Duplicate City, Skipping.
# Avarua is a Duplicate City, Skipping.
# Praia is a Duplicate City, Skipping.
# Makakilo City is a Duplicate City, Skipping.
# Butaritari is a Duplicate City, Skipping.
# City found: Dicamay, PH
# Jamestown is a Duplicate City, Skipping.
# Port Alfred is a Duplicate City, Skipping.
# Tiksi is a Duplicate City, Skipping.
# Kapaa is a Duplicate City, Skipping.
# Albany is a Duplicate City, Skipping.
# City Taolanaro not found in API! Skipping.
# City found: Atar, MR
# Qaanaaq is a Duplicate City, Skipping.
# Buala is a Duplicate City, Skipping.
# City Grand River South East not found in API! Skipping.
# Georgetown is a Duplicate City, Skipping.
# City Mataura not found in API! Skipping.
# Qaqortoq is a Duplicate City, Skipping.
# Hobart is a Duplicate City, Skipping.
# Provideniya is a Duplicate City, Skipping.
# Hermanus is a Duplicate City, Skipping.
# Busselton is a Duplicate City, Skipping.
# City found: Buraydah, SA
# City found: Pinotepa Nacional, MX
# Hofn is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# City found: Kupang, ID
# City found: Guozhen, CN
# City found: Rabak, SD
# City Saleaula not found in API! Skipping.
# Port Alfred is a Duplicate City, Skipping.
# City found: Manturovo, RU
# Jamestown is a Duplicate City, Skipping.
# Busselton is a Duplicate City, Skipping.
# Kapaa is a Duplicate City, Skipping.
# City found: Codajas, BR
# Ushuaia is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# Bengkulu is a Duplicate City, Skipping.
# Hermanus is a Duplicate City, Skipping.
# City found: Moyeuvre-Grande, FR
# Port Alfred is a Duplicate City, Skipping.
# City Grand River South East not found in API! Skipping.
# City found: Mayabon, PH
# Barrow is a Duplicate City, Skipping.
# City found: San Vicente De Chucuri, CO
# City found: Sangmelima, CM
# City found: Pacific Grove, US
# Barrow is a Duplicate City, Skipping.
# City found: Sola, VU
# City Belushya Guba not found in API! Skipping.
# City found: Jiayuguan, CN
# Hermanus is a Duplicate City, Skipping.
# City Samusu not found in API! Skipping.
# City found: Qarqin, AF
# Hofn is a Duplicate City, Skipping.
# Labuhan is a Duplicate City, Skipping.
# Puerto Ayora is a Duplicate City, Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# City found: Tiznit, MA
# Busselton is a Duplicate City, Skipping.
# Kaitangata is a Duplicate City, Skipping.
# Port Lincoln is a Duplicate City, Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# Mahebourg is a Duplicate City, Skipping.
# Hermanus is a Duplicate City, Skipping.
# City Samusu not found in API! Skipping.
# Port Lincoln is a Duplicate City, Skipping.
# Tiznit is a Duplicate City, Skipping.
# City found: Alasehir, TR
# Leh is a Duplicate City, Skipping.
# City found: Lavrentiya, RU
# Bredasdorp is a Duplicate City, Skipping.
# Itarema is a Duplicate City, Skipping.
# Paamiut is a Duplicate City, Skipping.
# Cidreira is a Duplicate City, Skipping.
# City found: Alofi, NU
# Jamestown is a Duplicate City, Skipping.
# City found: Volksrust, ZA
# Ushuaia is a Duplicate City, Skipping.
# City found: Uvalde, US
# City Phan Rang not found in API! Skipping.
# City found: Idritsa, RU
# Longyearbyen is a Duplicate City, Skipping.
# Port Alfred is a Duplicate City, Skipping.
# City found: Bilma, NE
# Bluff is a Duplicate City, Skipping.
# Chokurdakh is a Duplicate City, Skipping.
# New Norfolk is a Duplicate City, Skipping.
# Upernavik is a Duplicate City, Skipping.
# Hermanus is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# City found: Oranjemund, NA
# Rikitea is a Duplicate City, Skipping.
# City found: Jurmala, LV
# Lompoc is a Duplicate City, Skipping.
# Hermanus is a Duplicate City, Skipping.
# City Vaitupu not found in API! Skipping.
# City found: Mantua, CU
# Ushuaia is a Duplicate City, Skipping.
# New Norfolk is a Duplicate City, Skipping.
# City found: At-Bashi, KG
# Bredasdorp is a Duplicate City, Skipping.
# Makakilo City is a Duplicate City, Skipping.
# Avarua is a Duplicate City, Skipping.
# City found: Russell, NZ
# Port Elizabeth is a Duplicate City, Skipping.
# Saint-Philippe is a Duplicate City, Skipping.
# Kodiak is a Duplicate City, Skipping.
# City Rungata not found in API! Skipping.
# Pangnirtung is a Duplicate City, Skipping.
# Faanui is a Duplicate City, Skipping.
# City found: Kailua, US
# Tuktoyaktuk is a Duplicate City, Skipping.
# City Illoqqortoormiut not found in API! Skipping.
# City Samusu not found in API! Skipping.
# City found: Santa Maria, CV
# Rikitea is a Duplicate City, Skipping.
# City found: Broome, AU
# Bredasdorp is a Duplicate City, Skipping.
# Port Alfred is a Duplicate City, Skipping.
# Carnarvon is a Duplicate City, Skipping.
# City found: Allada, BJ
# Korla is a Duplicate City, Skipping.
# Nanortalik is a Duplicate City, Skipping.
# Norman Wells is a Duplicate City, Skipping.
# Lompoc is a Duplicate City, Skipping.
# Lagoa is a Duplicate City, Skipping.
# Hambantota is a Duplicate City, Skipping.
# City Taolanaro not found in API! Skipping.
# Cidreira is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# Rio Gallegos is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# City Asau not found in API! Skipping.
# City found: Saint-Pierre, PM
# Barrow is a Duplicate City, Skipping.
# Cabo San Lucas is a Duplicate City, Skipping.
# City found: Chicama, PE
# San Cristobal is a Duplicate City, Skipping.
# Vaini is a Duplicate City, Skipping.
# Hobart is a Duplicate City, Skipping.
# Bambous Virieux is a Duplicate City, Skipping.
# Arraial Do Cabo is a Duplicate City, Skipping.
# Rikitea is a Duplicate City, Skipping.
# Saint-Philippe is a Duplicate City, Skipping.
# Castro is a Duplicate City, Skipping.
# Bredasdorp is a Duplicate City, Skipping.
# Bethel is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# City found: Santa Isabel Do Rio Negro, BR
# City found: Kuala Terengganu, MY
# Atuona is a Duplicate City, Skipping.
# City found: Jiangyou, CN
# City found: Maldonado, UY
# City Mataura not found in API! Skipping.
# Saint-Philippe is a Duplicate City, Skipping.
# City found: Sao Felix Do Xingu, BR
# City found: Calgary, CA
# City Tsihombe not found in API! Skipping.
# City found: Roald, NO
# City found: Pithoragarh, IN
# Clyde River is a Duplicate City, Skipping.
# City found: Harper, LR
# City found: Parakai, NZ
# Thompson is a Duplicate City, Skipping.
# Hilo is a Duplicate City, Skipping.
# City found: Urubicha, BO
# Talnakh is a Duplicate City, Skipping.
# City found: Meadow Lake, CA
# Mar Del Plata is a Duplicate City, Skipping.
# Cururupu is a Duplicate City, Skipping.
# City Lata not found in API! Skipping.
# Georgetown is a Duplicate City, Skipping.
# City found: Tarecuato, MX
# City found: Sur, OM
# Bilibino is a Duplicate City, Skipping.
# Hilo is a Duplicate City, Skipping.
# Hobart is a Duplicate City, Skipping.
# City found: Zhavoronki, RU
# City Taolanaro not found in API! Skipping.
# Hilo is a Duplicate City, Skipping.
# Rikitea is a Duplicate City, Skipping.
# Bluff is a Duplicate City, Skipping.
# Busselton is a Duplicate City, Skipping.
# City found: Uray, RU
# Rikitea is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# Tuatapere is a Duplicate City, Skipping.
# City found: Oranjestad, AW
# Lazaro Cardenas is a Duplicate City, Skipping.
# Kruisfontein is a Duplicate City, Skipping.
# City Mataura not found in API! Skipping.
# City found: Bodden Town, KY
# City found: Ben Tre, VN
# Ushuaia is a Duplicate City, Skipping.
# Port Alfred is a Duplicate City, Skipping.
# Jamestown is a Duplicate City, Skipping.
# Waingapu is a Duplicate City, Skipping.
# City Airai not found in API! Skipping.
# Qaanaaq is a Duplicate City, Skipping.
# City Nizhneyansk not found in API! Skipping.
# Hobart is a Duplicate City, Skipping.
# Nikolskoye is a Duplicate City, Skipping.
# Hermanus is a Duplicate City, Skipping.
# City Taolanaro not found in API! Skipping.
# City found: Kysyl-Syr, RU
# City Taolanaro not found in API! Skipping.
# City found: Lima, PE
# Longyearbyen is a Duplicate City, Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# City Staryy Biser not found in API! Skipping.
# City found: Caravelas, BR
# City Mataura not found in API! Skipping.
# City found: Sidvokodvo, SZ
# Broken Hill is a Duplicate City, Skipping.
# City found: Antofagasta, CL
# Ushuaia is a Duplicate City, Skipping.
# Mar Del Plata is a Duplicate City, Skipping.
# Avarua is a Duplicate City, Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# City Nizhneyansk not found in API! Skipping.
# Castro is a Duplicate City, Skipping.
# City found: La Sarre, CA
# Severo-Kurilsk is a Duplicate City, Skipping.
# Albany is a Duplicate City, Skipping.
# Cape Town is a Duplicate City, Skipping.
# City Mataura not found in API! Skipping.
# Carnarvon is a Duplicate City, Skipping.
# City Mys Shmidta not found in API! Skipping.
# City found: Funehiki, JP
# City found: Eureka, US
# City found: Guiglo, CI
# City found: Ponta Delgada, PT
# City found: Erenhot, CN
# City found: Jalu, LY
# Punta Arenas is a Duplicate City, Skipping.
# Ambilobe is a Duplicate City, Skipping.
# Albany is a Duplicate City, Skipping.
# City found: Veinticinco De Mayo, AR
# Puerto Ayora is a Duplicate City, Skipping.
# City found: Monrovia, LR
# City Eldikan not found in API! Skipping.
# Rikitea is a Duplicate City, Skipping.
# City found: Plettenberg Bay, ZA
# City found: Estevan, CA
# Hobart is a Duplicate City, Skipping.
# Jamestown is a Duplicate City, Skipping.
# Rikitea is a Duplicate City, Skipping.
# Albany is a Duplicate City, Skipping.
# City found: Coruripe, BR
# City found: Sulangan, PH
# City Mataura not found in API! Skipping.
# Tuktoyaktuk is a Duplicate City, Skipping.
# Albany is a Duplicate City, Skipping.
# City Illoqqortoormiut not found in API! Skipping.
# City found: Laguna, BR
# City found: Cambuquira, BR
# Punta Arenas is a Duplicate City, Skipping.
# Carnarvon is a Duplicate City, Skipping.
# Rikitea is a Duplicate City, Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# City found: Mwinilunga, ZM
# Vardo is a Duplicate City, Skipping.
# Albany is a Duplicate City, Skipping.
# City found: Mengyin, CN
# Dikson is a Duplicate City, Skipping.
# Punta Arenas is a Duplicate City, Skipping.
# Hilo is a Duplicate City, Skipping.
# City found: Cap Malheureux, MU
# Punta Arenas is a Duplicate City, Skipping.
# Georgetown is a Duplicate City, Skipping.
# City Taolanaro not found in API! Skipping.
# Pevek is a Duplicate City, Skipping.
# Cidreira is a Duplicate City, Skipping.
# City found: Corning, US
# Arraial Do Cabo is a Duplicate City, Skipping.
# Kaitangata is a Duplicate City, Skipping.
# Atuona is a Duplicate City, Skipping.
# City found: Gunjur, GM
# City found: Ljungby, SE
# City found: Xiashi, CN
# City found: Asosa, ET
# Kapaa is a Duplicate City, Skipping.
# Ushuaia is a Duplicate City, Skipping.
# Rocha is a Duplicate City, Skipping.
# Cidreira is a Duplicate City, Skipping.
# Lorengau is a Duplicate City, Skipping.
# City Barentsburg not found in API! Skipping.
# Hobart is a Duplicate City, Skipping.
# Port Macquarie is a Duplicate City, Skipping.
# Hermanus is a Duplicate City, Skipping.
# Laguna is a Duplicate City, Skipping.
# Esperance is a Duplicate City, Skipping.
# Xining is a Duplicate City, Skipping.
# Avarua is a Duplicate City, Skipping.
# Ribeira Grande is a Duplicate City, Skipping.
# City found: Aleksandrov Gay, RU
# City found: Krasnoselkup, RU
# City found: Shenjiamen, CN
# Ilulissat is a Duplicate City, Skipping.
# City found: Guantanamo, CU
# Ushuaia is a Duplicate City, Skipping.
# Kapaa is a Duplicate City, Skipping.
# City Illoqqortoormiut not found in API! Skipping.
# Carnarvon is a Duplicate City, Skipping.
# Souillac is a Duplicate City, Skipping.
# Saldanha is a Duplicate City, Skipping.
# Kodiak is a Duplicate City, Skipping.
# City Mataura not found in API! Skipping.
# Dikson is a Duplicate City, Skipping.
# City found: Soure, BR
# City found: Tual, ID
# Hermanus is a Duplicate City, Skipping.
# City Mataura not found in API! Skipping.
# Yellowknife is a Duplicate City, Skipping.
# Jamestown is a Duplicate City, Skipping.
# Rikitea is a Duplicate City, Skipping.
# City found: Shush, IR
# City found: Ken Caryl, US
#                   City Country  Lattitude  Longitude  Temperature C  \
# 0             Besancon      FR    47.2488     6.0182           2.37
# 1         Punta Arenas      CL   -53.1500   -70.9167           4.15
# 2            Roebourne      AU   -20.7833   117.1333          29.74
# 3             Saldanha      ZA   -33.0117    17.9442          23.15
# 4              Rikitea      PF   -23.1203  -134.9692          26.59
# 5             Souillac      MU   -20.5167    57.5167          29.15
# 6            Jamestown      SH   -15.9387    -5.7168          21.17
# 7              Aklavik      CA    68.2191  -135.0107         -24.85
# 8         Port Lincoln      AU   -34.7333   135.8667          21.97
# 9               Hobart      AU   -42.8794   147.3294          17.15
# 10      Ribeira Grande      PT    38.5167   -28.7000          16.15
# 11        Rio Gallegos      AR   -51.6226   -69.2181           4.15
# 12          Kaitangata      NZ   -46.2817   169.8464          10.65
# 13  North Myrtle Beach      US    33.8160   -78.6800           5.15
# 14              Hasaki      JP    35.7333   140.8333          14.15
# 15            Cidreira      BR   -30.1811   -50.2056          22.58
# 16           Fairbanks      US    64.8378  -147.7164         -22.63
# 17             Ushuaia      AR   -54.8000   -68.3000           3.15
# 18            Tasiilaq      GL    65.6145   -37.6368          -2.85
# 19                Naze      JP    28.3667   129.4833          22.15
# 20              Kodiak      US    57.7900  -152.4072          -1.85
# 21             Prestea      GH     5.4327    -2.1428          32.44
# 22             Kuching      MY     1.5500   110.3333          30.15
# 23                Aksu      KZ    52.0333    76.9167           2.15
# 24             Salalah      OM    17.0151    54.0924          30.15
# 25             Iquitos      PE    -3.7481   -73.2472          24.15
# 26              Dikson      RU    73.5069    80.5464         -29.27
# 27               Rocha      UY   -34.4833   -54.3333          14.92
# 28        Constitucion      MX    23.9912  -104.6749           5.74
# 29               Korla      CN    41.7597    86.1469           9.85
# 30             Paamiut      GL    61.9940   -49.6678          -1.67
# 31         Tuktoyaktuk      CA    69.4541  -133.0374         -26.50
# 32               Casma      PE    -9.4734   -78.2996          22.39
# 33              Jieshi      CN    22.8134   115.8257          26.82
# 34      Vestmannaeyjar      IS    63.4427   -20.2734           4.15
# 35            Dubrovka      RU    53.6907    33.5071           1.15
# 36               Bluff      NZ   -46.6000   168.3333          14.04
# 37             Talnakh      RU    69.4865    88.3972         -29.76
# 38             Husavik      IS    66.0449   -17.3389           4.15
# 39            Seymchan      RU    62.8833   152.4333         -25.17
# 40            Felanitx      ES    39.4696     3.1483          10.15
# 41            Lorengau      PG    -2.0226   147.2712          28.69
# 42        San Patricio      MX    19.2167  -104.7000          21.47
# 43              Ayagoz      KZ    47.9714    80.4392          -1.20
# 44      Port Macquarie      AU   -31.4333   152.9167          23.15
# 45        Puerto Ayora      EC    -0.7393   -90.3518          24.04
# 46         Grand Gaube      MU   -20.0064    57.6608          29.04
# 47        Santa Isabel      MX    28.3833  -113.3500          13.74
# 48            Victoria      SC    -4.6167    55.4500          32.15
# 49                Chuy      UY   -33.6971   -53.4616          19.13
#
#     Temperature F  Humidity %  Cloudiness %  Wind Speed (mph)
# 0          38.066        39.0           0.0            3.0016
# 1          41.270        70.0          40.0            8.0640
# 2          87.332        43.0          49.0           21.5936
# 3          75.470        46.0           1.0           18.4352
# 4          81.662        77.0          84.0            9.5424
# 5          86.270        74.0          75.0           10.3712
# 6          71.906        73.0          23.0           20.1376
# 7         -10.930        77.0          13.0            2.3072
# 8          73.346        63.0           0.0           14.2016
# 9          64.670        67.0          20.0           13.8208
# 10         62.870        88.0          40.0           16.1280
# 11         41.270        75.0           0.0           11.5136
# 12         52.970        95.0          45.0            5.1296
# 13         43.070        56.0          90.0            9.2288
# 14         59.270        88.0          75.0            5.7568
# 15         74.444        81.0          29.0           17.4048
# 16         -6.934        70.0           1.0            6.9216
# 17         39.470        87.0          90.0           13.8208
# 18         28.670        86.0          90.0            9.2288
# 19         73.670        94.0          75.0           11.5136
# 20         30.470        86.0          90.0            4.6144
# 21         92.192        57.0          80.0            1.2544
# 22         88.070        74.0          40.0            8.0640
# 23         37.670        69.0           0.0           17.9200
# 24         88.070        54.0           0.0           11.5136
# 25         77.270        94.0          75.0            1.1424
# 26        -18.886        89.0          92.0           18.0544
# 27         60.656        96.0          93.0            5.6672
# 28         44.132        56.0           0.0            1.2320
# 29         51.530        35.0          38.0            6.8096
# 30         30.794        89.0          38.0           16.3072
# 31        -13.900        99.0          77.0            8.5792
# 32         74.102        68.0          92.0            2.3744
# 33         82.076        74.0           0.0            3.0016
# 34         41.270        81.0          75.0           17.2928
# 35         35.870        69.0          40.0            4.4800
# 36         59.072        85.0          45.0            6.0032
# 37        -19.768        85.0           0.0            1.9712
# 38         41.270        52.0          40.0           10.3712
# 39        -11.506        98.0          17.0            1.5008
# 40         52.070        87.0          75.0           20.7424
# 41         85.442        71.0          97.0            5.5328
# 42         72.446        54.0           0.0            2.8448
# 43         31.640        82.0          98.0            3.3824
# 44         75.470        88.0          75.0           16.1280
# 45         77.072        97.0          60.0            1.9936
# 46         86.072        74.0          33.0           12.0064
# 47         58.532        37.0           1.0            2.7552
# 48         91.670        58.0          20.0           14.9856
# 49         68.234        91.0          33.0            9.5424

# %%
fig1 = plt.scatter(City_df['Lattitude'],City_df['Temperature C'])
plt.title('Lattitude vs Temperature')
plt.xlabel('Lattitude')
plt.xlim(-80, 80)
plt.ylabel('Temperature C')
plt.ylim(-40,40)
plt.show()

# %%
fig2 = plt.scatter(City_df['Lattitude'],City_df['Humidity %'])
plt.title('Lattitude vs Humidity')
plt.xlabel('Lattitude')
plt.xlim(-80, 80)
plt.ylabel('Humidity %')
plt.ylim(0,105)
plt.show()

# %%
fig3 = plt.scatter(City_df['Lattitude'],City_df['Cloudiness %'])
plt.title('Lattitude vs Cloudiness')
plt.xlabel('Lattitude')
plt.xlim(-80, 80)
plt.ylabel('Cloudiness %')
plt.ylim(-2,102)
plt.show()

# %%
fig4 = plt.scatter(City_df['Lattitude'],City_df['Wind Speed (mph)'])
plt.title('Lattitude vs Wind Speed')
plt.xlabel('Lattitude')
plt.xlim(-80, 80)
plt.ylabel('Wind Speed (mph)')
plt.ylim(-2,35)
plt.show()

# %%
# Hemispheric Analysis Dataframes 

NorthernHemisphere_df = City_df.loc[(City_df['Lattitude'] > 0)]
SouthernHemisphere_df = City_df.loc[(City_df['Lattitude'] < 0)]

# %%
graph1 = plt.scatter(NorthernHemisphere_df['Lattitude'],NorthernHemisphere_df['Temperature C'])
plt.xlabel('Lattitude')
plt.ylabel('Temperature')
plt.title('Northern Hemisphere Temperature vs Lattitude')
plt.ylim(-40, 40)
g1_slope, g1_int, g1_r, g1_p, g1_std_err = stats.linregress(NorthernHemisphere_df['Lattitude'],NorthernHemisphere_df['Temperature C'])
g1_fit = g1_slope * NorthernHemisphere_df['Lattitude'] + g1_int
plt.plot(NorthernHemisphere_df['Lattitude'],g1_fit,"--")

plt.savefig(savefolder + 'Northern Hemisphere Temperature vs Lattitude.jpg', dpi = 300)

plt.show()

# %%
graph2 = plt.scatter(SouthernHemisphere_df['Lattitude'],SouthernHemisphere_df['Temperature C'])
plt.xlabel('Lattitude')
plt.ylabel('Temperature')
plt.ylim(-40, 40)
plt.title('Southern Hemisphere Temperature vs Lattitude')
g2_slope, g2_int, g2_r, g2_p, g2_std_err = stats.linregress(SouthernHemisphere_df['Lattitude'],SouthernHemisphere_df['Temperature C'])
g2_fit = g2_slope * SouthernHemisphere_df['Lattitude'] + g2_int
plt.plot(SouthernHemisphere_df['Lattitude'],g2_fit,"--")

plt.savefig(savefolder + 'Southern Hemisphere Temperature vs Lattitude.jpg', dpi = 300)

plt.show()

# %%
graph3 = plt.scatter(NorthernHemisphere_df['Lattitude'],NorthernHemisphere_df['Humidity %'])
plt.xlabel('Lattitude')
plt.ylabel('Humidity %')
plt.title('Northern Hemisphere Humidity vs Lattitude')
g3_slope, g3_int, g3_r, g3_p, g3_std_err = stats.linregress(NorthernHemisphere_df['Lattitude'],NorthernHemisphere_df['Humidity %'])
g3_fit = g3_slope * NorthernHemisphere_df['Lattitude'] + g3_int
plt.plot(NorthernHemisphere_df['Lattitude'],g3_fit,"--")

plt.savefig(savefolder + 'Northern Hemisphere Humidity vs Lattitude.jpg', dpi = 300)

plt.show()

# %%
graph4 = plt.scatter(SouthernHemisphere_df['Lattitude'],SouthernHemisphere_df['Humidity %'])
plt.xlabel('Lattitude')
plt.ylabel('Humidity %')
plt.title('Southern Hemisphere Humidity vs Lattitude')
g4_slope, g4_int, g4_r, g4_p, g4_std_err = stats.linregress(SouthernHemisphere_df['Lattitude'],SouthernHemisphere_df['Humidity %'])
g4_fit = g4_slope * SouthernHemisphere_df['Lattitude'] + g4_int
plt.plot(SouthernHemisphere_df['Lattitude'],g4_fit,"--")

plt.savefig(savefolder + 'Southern Hemisphere Humidity vs Lattitude.jpg', dpi = 300)

plt.show()

# %%
graph5 = plt.scatter(NorthernHemisphere_df['Lattitude'],NorthernHemisphere_df['Cloudiness %'])
plt.xlabel('Lattitude')
plt.ylabel('Cloudiness %')
plt.title('Northern Hemisphere Cloudiness vs Lattitude')
g5_slope, g5_int, g5_r, g5_p, g5_std_err = stats.linregress(NorthernHemisphere_df['Lattitude'],NorthernHemisphere_df['Cloudiness %'])
g5_fit = g5_slope * NorthernHemisphere_df['Lattitude'] + g5_int
plt.plot(NorthernHemisphere_df['Lattitude'],g5_fit,"--")

plt.savefig(savefolder + 'Northern Hemisphere Cloudiness vs Lattitude.jpg', dpi = 300)

plt.show()

# %%
graph6 = plt.scatter(SouthernHemisphere_df['Lattitude'],SouthernHemisphere_df['Cloudiness %'])
plt.xlabel('Lattitude')
plt.ylabel('Cloudiness %')
plt.title('Southern Hemisphere Cloudiness vs Lattitude')
g6_slope, g6_int, g6_r, g6_p, g6_std_err = stats.linregress(SouthernHemisphere_df['Lattitude'],SouthernHemisphere_df['Cloudiness %'])
g6_fit = g6_slope * SouthernHemisphere_df['Lattitude'] + g6_int
plt.plot(SouthernHemisphere_df['Lattitude'],g6_fit,"--")

plt.savefig(savefolder + 'Southern Hemisphere Cloudiness vs Lattitude.jpg', dpi = 300)

plt.show()

# %%
graph7 = plt.scatter(NorthernHemisphere_df['Lattitude'],NorthernHemisphere_df['Wind Speed (mph)'])
plt.xlabel('Lattitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere Wind Speed vs Lattitude')
g7_slope, g7_int, g7_r, g7_p, g7_std_err = stats.linregress(NorthernHemisphere_df['Lattitude'],NorthernHemisphere_df['Wind Speed (mph)'])
g7_fit = g7_slope * NorthernHemisphere_df['Lattitude'] + g7_int
plt.plot(NorthernHemisphere_df['Lattitude'],g7_fit,"--")

plt.savefig(savefolder + 'Northern Hemisphere Wind Speed vs Lattitude.jpg', dpi = 300)

plt.show()

# %%
graph8 = plt.scatter(SouthernHemisphere_df['Lattitude'],SouthernHemisphere_df['Wind Speed (mph)'])
plt.xlabel('Lattitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere Wind Speed vs Lattitude')
g8_slope, g8_int, g8_r, g8_p, g8_std_err = stats.linregress(SouthernHemisphere_df['Lattitude'],SouthernHemisphere_df['Wind Speed (mph)'])
g8_fit = g8_slope * SouthernHemisphere_df['Lattitude'] + g8_int
plt.plot(SouthernHemisphere_df['Lattitude'],g8_fit,"--")

plt.savefig(savefolder + 'Southern Hemisphere Wind Speed vs Lattitude.jpg', dpi = 300)

plt.show()
